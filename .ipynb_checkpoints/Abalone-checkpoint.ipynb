# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Abalone-Dataset" data-toc-modified-id="Abalone-Dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Abalone Dataset</a></span></li><li><span><a href="#Introduction" data-toc-modified-id="Introduction-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Data-Description" data-toc-modified-id="Data-Description-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Description</a></span></li><li><span><a href="#Continuous-Attributes" data-toc-modified-id="Continuous-Attributes-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Continuous Attributes</a></span></li><li><span><a href="#Integer-Attributes" data-toc-modified-id="Integer-Attributes-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Integer Attributes</a></span></li><li><span><a href="#Nominal-Attributes" data-toc-modified-id="Nominal-Attributes-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Nominal Attributes</a></span></li></ul></li><li><span><a href="#Setup" data-toc-modified-id="Setup-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Load-Libraries" data-toc-modified-id="Load-Libraries-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Load Libraries</a></span></li><li><span><a href="#Define-Custom-Function" data-toc-modified-id="Define-Custom-Function-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Define Custom Function</a></span></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Load Data</a></span></li><li><span><a href="#Check-Data-Structure" data-toc-modified-id="Check-Data-Structure-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Check Data Structure</a></span></li><li><span><a href="#Add-Column-Names" data-toc-modified-id="Add-Column-Names-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Add Column Names</a></span></li><li><span><a href="#Data-Summary" data-toc-modified-id="Data-Summary-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Data Summary</a></span></li><li><span><a href="#Data-Type-Objects" data-toc-modified-id="Data-Type-Objects-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Data Type Objects</a></span></li></ul></li><li><span><a href="#Missing-Data" data-toc-modified-id="Missing-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Missing Data</a></span></li><li><span><a href="#Visualisation" data-toc-modified-id="Visualisation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Visualisation</a></span><ul class="toc-item"><li><span><a href="#Histogram" data-toc-modified-id="Histogram-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Histogram</a></span></li><li><span><a href="#Pie-Chart" data-toc-modified-id="Pie-Chart-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Pie Chart</a></span></li><li><span><a href="#Bar-Graph" data-toc-modified-id="Bar-Graph-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Bar Graph</a></span></li></ul></li><li><span><a href="#Distribution-Evaluations" data-toc-modified-id="Distribution-Evaluations-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Distribution Evaluations</a></span><ul class="toc-item"><li><span><a href="#Skew" data-toc-modified-id="Skew-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Skew</a></span></li><li><span><a href="#Kurtosis" data-toc-modified-id="Kurtosis-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Kurtosis</a></span></li><li><span><a href="#Outliers" data-toc-modified-id="Outliers-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Outliers</a></span></li></ul></li><li><span><a href="#One-Hot-Encoding" data-toc-modified-id="One-Hot-Encoding-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>One-Hot-Encoding</a></span></li><li><span><a href="#Statistical-Model" data-toc-modified-id="Statistical-Model-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Statistical Model</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression-via-OLS" data-toc-modified-id="Linear-Regression-via-OLS-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Linear Regression via OLS</a></span></li></ul></li><li><span><a href="#Check-Assumptions" data-toc-modified-id="Check-Assumptions-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Check Assumptions</a></span><ul class="toc-item"><li><span><a href="#Linearity" data-toc-modified-id="Linearity-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Linearity</a></span></li><li><span><a href="#Normality-Of-Error" data-toc-modified-id="Normality-Of-Error-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Normality Of Error</a></span></li><li><span><a href="#Variance-Inflation" data-toc-modified-id="Variance-Inflation-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Variance Inflation</a></span></li><li><span><a href="#Homoskedasticity" data-toc-modified-id="Homoskedasticity-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Homoskedasticity</a></span></li></ul></li><li><span><a href="#Itteratively-Remove-Highest-VIF-Features" data-toc-modified-id="Itteratively-Remove-Highest-VIF-Features-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Itteratively Remove Highest VIF Features</a></span></li><li><span><a href="#Model-Evaluation" data-toc-modified-id="Model-Evaluation-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Model Evaluation</a></span><ul class="toc-item"><li><span><a href="#Learning-Curve" data-toc-modified-id="Learning-Curve-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Learning Curve</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Abalone Dataset

# %% [markdown]
# # Introduction
# Abalone is the common name for marine snails found primarily in the UK, Austrailia, and South Africa. The age of an abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age.  Here, we will try to use various abalone features to build a model for predicting abalone age.

# %% [markdown]
# ## Data Description
# These data come from a 1994 study titled: "The Population Biology of Abalone (_Haliotis_ species) in Tasmania. I. Blacklip Abalone (_H. rubra_) from the North Coast and Islands of Bass Strait".

# %% [markdown]
# ## Continuous Attributes
# - *Length*: Longest shell measurement (mm)
# - *Diameter*: Perpendicular to length (mm)
# - *Height*: With meat in shell (mm)
# - *Whole weight*: Whole abalone (g)
# - *Shucked weight*: Weight of meat (g)
# - *Viscera weight*: Gut weight after bleeding (g)
# - *Shell weight*: After being dried (g)
#
# ## Integer Attributes
# - *Rings*: +1.5 gives the age in years
#
# ## Nominal Attributes
# - *Sex*: Male (M), Female (F), and Infant (I)

# %% [markdown]
# # Setup

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
from numpy import arange
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV, train_test_split, learning_curve, GridSearchCV, RepeatedKFold, validation_curve
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from collections import Counter
import pylab as pl
from pandas.plotting import scatter_matrix
from scipy.stats import skew, kurtosis, shapiro
from statsmodels.graphics.gofplots import qqplot
from statsmodels.stats.outliers_influence import variance_inflation_factor
#from sklearn.linear_model import LogisticRegression
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
#from pandas import read_csv
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Define Custom Function

# %%
######################### Skew function #########################
def Skew_Abalone(Dataframe):
    """
    Print number of predictors at a given Skew cutoff
    """
    # Create lists for different skew levels.
    No_Skew, Moderate_Skew, Severe_Skew = ([] for i in range(3))
    
    # Assign each skew score to a list.
    for i in range(len(Dataframe.loc[:, Dataframe.columns != 'Rings'].skew(axis = 0))):
        count = Dataframe.loc[:, Dataframe.columns != 'Rings'].skew(axis = 0)[i]
        
        # Determine skew.
        if count < 0.5 and count > -0.5:
            No_Skew.append(count)
        elif count > 0.5 and count < -0.5 or count < 1 and count > -1:
            Moderate_Skew.append(count)
        else:
            Severe_Skew.append(count)

    # Print skew scores for each level.
    print('No Skew:', len(No_Skew))
    print('Moderate Skew:', len(Moderate_Skew))
    print('Severe Skew:', len(Severe_Skew))


######################### Kurtosis function #########################
def Kurtosis_Abalone(Dataframe):
    """
    Print number of predictors at a given Kurtosis cutoff
    """
    # Create lists for different skew levels.
    No_Kurtosis, Moderate_Kurtosis, Severe_Kurtosis = ([] for i in range(3))
    
    # Assign each skew score to a list.
    for i in range(len(Dataframe.loc[:, Dataframe.columns != 'Rings'].kurtosis(axis = 0))):
        count = Dataframe.loc[:, Dataframe.columns != 'Rings'].kurtosis(axis = 0)[i]
        if count < 3 and count > -3:
            No_Kurtosis.append(count)
        elif count > 3 and count < -3 or count < 7 and count > -7:
            Moderate_Kurtosis.append(count)
        else:
            Severe_Kurtosis.append(count)

    # Print skew scores for each level.
    print('No Kurtosis:', len(No_Kurtosis))
    print('Moderate Kurtosis:', len(Moderate_Kurtosis))
    print('Severe Kurtosis:', len(Severe_Kurtosis))


######################### Regression function #########################
def regression_function(X,y):
    """
    Calculates linear model and outputs: train/validate/test shape, MSE, R2, and adjusted R2.
    """
    # Split data into training and testing sets.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

    # further divide the training data again to get a validation set.
    #X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.25, random_state = 1) # 0.25 x 0.8 = 0.2
    
    # Print size of training, validation, and testing set for verification.
    print('X_Train Shape =', round(X_train.shape[0]/4177 * 100),'%')
    #print('X_Validate Shape =', round(X_val.shape[0]/4177 * 100),'%')
    print('X_Test Shape =', round(X_test.shape[0]/4177 * 100),'%')
    print('') # Add space.
    
    # Call linearRegression function from scikitlearn.
    regr = linear_model.LinearRegression()
    
    # Fit regression model using predictor(s) (X_train) and dependent variable (y_train).
    regr.fit(X_train, y_train)
    
    # Print coefficients.
    print('Coefficients')
    print(regr.coef_)
    print('') # Add space.
    
    # Make predictions using the testing set
    y_pred = regr.predict(X_test)
    
    # Print mean squared error
    print('MSE =', mean_squared_error(y_test, y_pred))
    
    # Print coefficient of determination: 1 is perfect prediction
    print('R2 =', r2_score(y_test, y_pred))
    
    # Print adjusted coefficent of determination (model steadily accrues coefficient-driven penalty, penalising complex models).
    print('Adj_R2 =', (1 - (1 - r2_score(y_test, y_pred)) * ((X.shape[0] - 1) / (X.shape[0] - X.shape[1] - 1))))


######################### Function for testing linearity #########################
def calculate_residuals(model, features, label):
    """
    Creates predictions on the features with the model and calculates residuals
    """
    # vector of predicted response variables.
    predictions = model.predict(features)
    
    # Dataframe plotting labels against model predictions.
    df_results = pd.DataFrame({'Actual': label, 'Predicted': predictions})
    
    # Absolute difference between labels and predictions.
    df_results['Residuals'] = abs(df_results['Actual']) - abs(df_results['Predicted'])
    
    return df_results


######################### Funcion for testing normality #########################
def normal_errors_assumption(model, features, label, p_value_thresh = 0.05):
    """
    Normality: Assumes that the error terms are normally distributed. If they are not,
    nonlinear transformations of variables may solve this.
               
    This assumption being violated primarily causes issues with the confidence intervals
    """
    from statsmodels.stats.diagnostic import normal_ad
    print('Assumption 2: The error terms are normally distributed', '\n')
    
    # Calculating residuals for the Anderson-Darling test
    df_results = calculate_residuals(model, features, label)
    
    print('Using the Anderson-Darling test for normal distribution')

    # Performing the test on the residuals
    p_value = normal_ad(df_results['Residuals'])[1]
    print('p-value from the test - below 0.05 generally means non-normal:', p_value)
    
    # Reporting the normality of the residuals
    if p_value < p_value_thresh:
        print('Residuals are not normally distributed')
    else:
        print('Residuals are normally distributed')
    
    # Plotting the residuals distribution
    plt.subplots(figsize=(12, 6))
    plt.title('Distribution of Residuals')
    sns.distplot(df_results['Residuals'])
    plt.show()
    
    print()
    if p_value > p_value_thresh:
        print('Assumption satisfied')
    else:
        print('Assumption not satisfied')
        print()
        print('Confidence intervals will likely be affected')
        print('Try performing nonlinear transformations on variables')


######################### Polynomial regression function #########################
def PolynomialRegression(degree = 2, **kwargs):
    """
    Create a pipeline for polynomail regression.
    """
    # Return polynomial pipeline.
    return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))


######################### Split Rings function #########################
def abalone_split(dataframe, split):
    """
    Splits dependent variable in 2 or 3 groups.
    """
    # Copy abalone dataframe.
    abalone_two = abalone.copy()
    
    # Empty list.
    Rings = []
    
    # Split by 2.
    if split == 2:
        # Perform mean split: Rings list stores 1 for abalone with more than 14.5 rings, and 0 otherwise.
        for i in abalone_two['Rings']:
            if i > 14.5:
                Rings.append('1')
            else:
                Rings.append('0')
   
    # Split by 3.            
    else:
        for i in abalone_two['Rings']:
            if i > 19.2:
                Rings.append('2')
            elif i > 9.6 and i < 19.2:
                Rings.append('1') 
            else:
                Rings.append('0')
                
    # Replace total Rings column with mean-split Rings column.
    abalone_two['Rings'] = Rings

    # See how many of each their are.
    abalone_two['Rings'].value_counts()
    
    # Return dataframe if split is 2 or 3.
    if split == 2 or split == 3:
        return(abalone_two)
    
    # Else, tell user to use split of 2 or 3.
    else:
        print("Can only split by 2 or 3. Please try again!")


######################### Scaled Regression function #########################
def scale_regression_function(X, y):
    """
    Calculates linear model and outputs: train/validate/test shape, MSE, R2, and adjusted R2.
    """
    
    num_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
    ])
    
    X_scaled = num_pipeline.fit_transform(X)
    
    # Split data into training and testing sets.
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state = 1)

    # further divide the training data again to get a validation set.
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.25, random_state = 1) # 0.25 x 0.8 = 0.2
    
    # Print size of training, validation, and testing set for verification.
    print('X_Train Shape =', round(X_train.shape[0]/4177 * 100),'%')
    print('X_Validate Shape =', round(X_val.shape[0]/4177 * 100),'%')
    print('X_Test Shape =', round(X_test.shape[0]/4177 * 100),'%')
    print('') # Add space.
    
    # Call linearRegression function from scikitlearn.
    regr = linear_model.LinearRegression()
    
    # Fit regression model using predictor(s) (X_train) and dependent variable (y_train).
    regr.fit(X_train, y_train)
    
    # Print coefficients.
    print('Coefficients')
    print(regr.coef_)
    print('') # Add space.
    
    # Make predictions using the testing set
    y_pred = regr.predict(X_val)
    
    # Print mean squared error
    print('MSE =', mean_squared_error(y_val, y_pred))
    
    # Print coefficient of determination: 1 is perfect prediction
    print('R2 =', r2_score(y_val, y_pred))
    
    # Print adjusted coefficent of determination (model steadily accrues coefficient-driven penalty, penalising complex models).
    print('Adj_R2 =', (1 - (1 - r2_score(y_val, y_pred)) * ((X.shape[0] - 1) / (X.shape[0] - X.shape[1] - 1))))

# %% [markdown]
# ## Load Data

# %%
# Import raw data.
abalone = pd.read_csv("C:\\Users\\STPI0560\\Desktop\\Python Projects\\Abalone\\abalone.data.csv", header = None)

# %% [markdown]
# ## Check Data Structure

# %%
# Look at the first few rows of the data.
abalone.head()
# Out:
#    0      1      2      3       4       5       6      7   8
# 0  M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.150  15
# 1  M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.070   7
# 2  F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.210   9
# 3  M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.155  10
# 4  I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.055   7

# %% [markdown]
# These data do not have column names. However, this dataset came with a readME.txt file containing all of this information. So, we can still manually add the names to the dataframe.

# %% [markdown]
# ## Add Column Names

# %%
# Manually add column names to dataframe.
abalone.columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_Weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']

# Look at the first few rows of the data to confirm column names are present.
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_Weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %% [markdown]
# Now the data have column names. Each row represents measurements taken from 1 abalone, and each column is a vector representing a single measured feature. The first 8 columns represent the predictors we will use to predict abalone age, and the final column ("Rings") is what we are going to use the features to try and predict. The first column in the dataframe is a categorical variable representing the sex of each abalone, and will need to be dealt with later to make it interpretable for the machine learning algorithm. The next subsequent 7 columns represent size and weight measurements, and the final column represents the number of rings counted for each abalone. Importantly, the age of an abalone can be calculated by adding 1.5 to its ring count.

# %% [markdown]
# Let's check out the number of rows, and number of features.

# %%
# Print out number of columns and rows.
print("Their are", abalone.shape[1], "columns.")
print("Their are", abalone.shape[0], "rows.")
# Out:
# Their are 9 columns.
# Their are 4177 rows.

# %% [markdown]
# ## Data Summary

# %%
# View various summary statistics.
abalone.describe(include = 'all')
# Out:
#          Sex       Length     Diameter       Height  Whole_Weight  \
# count   4177  4177.000000  4177.000000  4177.000000   4177.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1528          NaN          NaN          NaN           NaN
# mean     NaN     0.523992     0.407881     0.139516      0.828742
# std      NaN     0.120093     0.099240     0.041827      0.490389
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.350000     0.115000      0.441500
# 50%      NaN     0.545000     0.425000     0.140000      0.799500
# 75%      NaN     0.615000     0.480000     0.165000      1.153000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked weight  Viscera weight  Shell weight        Rings
# count      4177.000000     4177.000000   4177.000000  4177.000000
# ...

# %% [markdown]
# Because their are 4177 measurements for each feature, their are no missing values anywhere (although we will confirm this momentarily).Our only categorical variable is "Sex", with 3 unique values. Later, we will dummy code "Sex" so that we can use it in our model. The predictor is "Rings". Based on the Min and Max, it seems to take on discrete values from 1 to 29.
# All åredictors (other than sex) are continuous.

# %% [markdown]
# ## Data Type Objects

# %%
# Get a Series object containing the data type objects of each column of Dataframe.

# Index of series is column name.
dataTypeSeries = abalone.dtypes

# Print results.
print('Data type of each column of Dataframe :')
print(dataTypeSeries)
# Out:
# Data type of each column of Dataframe :
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole_Weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# The predictors are all float64 objects, meaning they have decimals. The dependent variable is and int64 object, meaning it is a whole number without decimals. The Sex variable is an object, and therefore categorical. As stated earlier, this needs to be dummy coded to use properly.

# %% [markdown]
# # Missing Data
# Although we know there are no missing values in the data, we should double check anyway.

# %%
# Small loop to find determine which columns have missing values present.
cols_with_missing = [col for col in abalone.columns if abalone[col].isnull().any()]

# Print a list of each column that has at least 1 missing value.
print('List of columns with missing values:')
print(cols_with_missing)
print('')
print('Number of missing values per column:')

# List each dataframe column and the number of missing values in each.
print(abalone.isnull().sum())
# Out:
# List of columns with missing values:
# []
#
# Number of missing values per column:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_Weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # Visualisation
# Let's see how the data are distributed. This can help us see whether the data are skewed, and whether their are any potential issues with multicollinearity (although multicolliniarity is more quantitatively diagnosed AFTER the model is fit).

# %% [markdown]
# ## Histogram

# %%
# Setup histogram layout.
abalone.hist(bins = 30, figsize = (10,5), layout = (2,4))

# Add title.
pl.suptitle("Histogram for each numeric input variable")

# Display histogram.
plt.show()

# %% [markdown]
# We can also explore the target variable "Rings". While it may not be as important for Linear Regression, it might be worth looking at how balanced the target variables are.

# %%
# Get how many abalone have each number of rings.
Rings_Count = pd.DataFrame(abalone['Rings'].value_counts(normalize=False))

# Change index to Age.
Rings_Count['Age'] = Rings_Count.index 

# Rename columns and do descending sort by Total.
Rings_Count.rename(columns = {"Rings":"Total", "Age":"Rings"}).sort_values(by = ['Total'], ascending = False)
# Out:
#     Total  Rings
# 9     689      9
# 10    634     10
# 8     568      8
# 11    487     11
# 7     391      7
# 12    267     12
# 6     259      6
# 13    203     13
# 14    126     14
# 5     115      5
# 15    103     15
# 16     67     16
# 17     58     17
# 4      57      4
# 18     42     18
# 19     32     19
# 20     26     20
# 3      15      3
# 21     14     21
# 23      9     23
# 22      6     22
# 27      2     27
# 24      2     24
# 26      1     26
# 29      1     29
# 25      1     25
# 1       1      1
# 2       1      2

# %% [markdown]
# There is certainly a wide variety of total rings. For instance, only 1 abalone had 29 rings, while 689 had 9 rings.

# %% [markdown]
# ## Pie Chart
# Pie charts can give us a quick visual reference relating to the relative proportion of rings.

# %%
# Plot quick pie chart with legend removed.
Rings_Count.plot.pie(y = 'Rings', figsize = (10, 10),legend = False)
# Out:
# <AxesSubplot:ylabel='Rings'>

# %% [markdown]
# ## Bar Graph
# In addition to the pie chart, we could also look at the relative number of ring counts using a bar graph.

# %%
# Plot quick bar graph of ring count.
Rings_Count.plot.bar(x = "Age", figsize = (10, 10))
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # Distribution Evaluations

# %% [markdown]
# ## Skew

# %% [markdown]
# Some of the data appear to be marginally skewed, and we can test this more formally. As a rule of thumb:
# <br>
# - Scores between -0.5 and 0.5 indicate a relatively normal distribution.
# <br>
# - Score between -0.5 and -1, or 0.5 and 1, indicate moderate skew.
# <br>
# - Score less than -1, or greater than 1, indicate highly skewed data.

# %%
# Display skew scores.
Skew_Abalone(abalone)
# Out:
# No Skew: 0
# Moderate Skew: 6
# Severe Skew: 1

# %%
# List skewness score for each feature, except the dependent variable.
abalone.loc[:, abalone.columns != 'Rings'].skew(axis = 0)
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole_Weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# dtype: float64

# %% [markdown]
# All features seem to be at least moderately skewed, with Height being severely skewed. This can affect heteroskedasticity, so it may be something we want to fix later on by transforming these variables.

# %% [markdown]
# ## Kurtosis

# %% [markdown]
# Kurtosis tells us how fat or thin the tails of each distribution are. Because the kurtosis of a normal distribution is 3 (sometimes called "mesokurtic"), we can use that as a general cutoff for each distribution. Thus, a kurtosis score tells us how different our distribution is from mesokurtic. Based on convention, we will call anything with a kurtosis score greater than 7 "severe".

# %%
# Display kurtosis scores.
Kurtosis_Abalone(abalone)
# Out:
# No Kurtosis: 6
# Moderate Kurtosis: 0
# Severe Kurtosis: 1

# %%
# List kurtosis score for each feature.
abalone.loc[:, abalone.columns != 'Rings'].kurtosis()
# Out:
# Length             0.064621
# Diameter          -0.045476
# Height            76.025509
# Whole_Weight      -0.023644
# Shucked weight     0.595124
# Viscera weight     0.084012
# Shell weight       0.531926
# dtype: float64

# %% [markdown]
# Clearly, there is some major issue with the Height feature. Let's quickly plot a histogram of it to see.

# %%
# Setup Histogram Layout.
abalone["Height"].hist(bins = 30, figsize = (15, 10))

# Add title.
pl.suptitle("Histogram for each numeric input variable")

# Plot histogram.
plt.show()

# %% [markdown]
# It's hard to see, but their are at least two values which are severe outliers. Could this be affecting skew and kurtosis? Let's find out!
# <br>
# Since it looks looks like their are only 2 values that are outliers, let's see what they are. Because they are above 0.4, let's just list are rows where height is above 0.4.

# %%
# List skewness score for each feature.
print("Rows with outlier Height:")

# Discpaly rows with height greater than 0.4.
abalone.loc[abalone['Height'] > 0.4]
# Out:
# Rows with outlier Height:
#      Sex  Length  Diameter  Height  Whole_Weight  Shucked weight  \
# 1417   M   0.705     0.565   0.515         2.210          1.1075
# 2051   F   0.455     0.355   1.130         0.594          0.3320
#
#       Viscera weight  Shell weight  Rings
# 1417          0.4865        0.5120     10
# 2051          0.1160        0.1335      8

# %% [markdown]
# Now, let's see what happens to our skew and kurtosis scores when we remove these 2 rows from the dataframe.

# %%
# Create lists for different skew levels.
No_Skew, Moderate_Skew, Severe_Skew = ([] for i in range(3))

# Assign each skew score to a list.
for i in range(len(abalone.loc[:, abalone.columns != 'Rings'].loc[abalone['Height'] < 0.4].skew(axis = 0))):
    count = abalone.loc[:, abalone.columns != 'Rings'].loc[abalone['Height'] < 0.4].skew(axis = 0)[i]
    if count < 0.5 and count > -0.5:
        No_Skew.append(count)
    elif count > 0.5 and count < -0.5 or count < 1 and count > -1:
        Moderate_Skew.append(count)
    else:
        Severe_Skew.append(count)

# Print skew scores for each level.
print("No Skew:", len(No_Skew))
print("Moderate Skew:", len(Moderate_Skew))
print("Severe Skew:", len(Severe_Skew))
# Out:
# No Skew: 1
# Moderate Skew: 6
# Severe Skew: 0

# %%
# Create lists for different skew levels.
No_Kurtosis, Moderate_Kurtosis, Severe_Kurtosis = ([] for i in range(3))

# Assign each skew score to a list.
for i in range(len(abalone.loc[:, abalone.columns != 'Rings'].loc[abalone['Height'] < 0.4].kurtosis(axis = 0))):
    count = abalone.loc[:, abalone.columns != 'Rings'].loc[abalone['Height'] < 0.4].kurtosis(axis = 0)[i]
    if count < 2 and count > -2:
        No_Kurtosis.append(count)
    elif count > 2 and count < -2 or count < 7 and count > -7:
        Moderate_Kurtosis.append(count)
    else:
        Severe_Kurtosis.append(count)

# Print skew scores for each level.
print("No Kurtosis:", len(No_Kurtosis))
print("Moderate Kurtosis:", len(Moderate_Kurtosis))
print("Severe Kurtosis:", len(Severe_Kurtosis))
# Out:
# No Kurtosis: 7
# Moderate Kurtosis: 0
# Severe Kurtosis: 0

# %% [markdown]
# It's clear that the removal of these 2 datapoints eliminates severe skew and severe kurtosis. Therefore, we should just remove those 2 rows from the dataset and move forward without them.

# %%
# Remove height outliers.
abalone = abalone.loc[abalone['Height'] < 0.4]

# Recheck rows.
abalone.shape
# Out:
# (4175, 9)

# %% [markdown]
# ## Outliers
# While I have no idea whether outliers will affect the model, it might be useful to run the regression both with and without outliers present to assess the RMSE in both.

# %%
# Setup box and whisker plot.
abalone.plot(kind = 'box', subplots = True, figsize = (15,10), layout = (2,4), sharex = False, sharey = False)

# Plot box and whisker plot.
plt.show()

# %% [markdown]
# It is very obvious that, at least using the IQR criterion, that all of our predictors have some outliers (and we can ignor ethe target outliers). The question is what to do with them. First, we could do nothing. Second, we could transform the data. Or, we could Winsorise the data. Finally, we could compute something like Cooks Distance to get a quantified account of outlier instance. Let's count up the number of outliers per predictor.

# %%
# Calculate outliers as per box and whisker plot criteria.
Q1 = abalone.quantile(0.25)
Q3 = abalone.quantile(0.75)
IQR = Q3 - Q1

# Display number of outliers for each predictor and dependent variable.
((abalone < (Q1 - 1.5 * IQR)) | (abalone > (Q3 + 1.5 * IQR))).sum()
# Out:
# C:\Users\STPI0560\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   import sys
# C:\Users\STPI0560\anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   import sys
# Diameter           59
# Height             27
# Length             49
# Rings             278
# Sex                 0
# Shell weight       35
# Shucked weight     47
# Viscera weight     26
# Whole_Weight       30
# dtype: int64

# %% [markdown]
# That is quite a few outliers, so perhaps they will affect our ability to make accurate predictions with our model. Before considering any outlier removal method, however, we should run a simple regression.

# %% [markdown]
# # One-Hot-Encoding
# The Column "Sex" is categorical, with 3 different categories. Let's see what they are.

# %%
# Display total for each abalone sex.
abalone["Sex"].value_counts()
# Out:
# M    1527
# I    1342
# F    1306
# Name: Sex, dtype: int64

# %% [markdown]
# Their are 3 unique values located in Sex: Male, Female, and Infant. All of which are mostly even in terms of total amount. We cannot use objects in a regression model, as python will give us an error. But we can't just replace the 3 unique values with unique digits. When you do this, the model assumes these refer to ranks. Here, Sex is not ranked, it is just an indicator. Thus,  we need to make 3 columns, each with a 1 to indicate that row is part of that Sex, and a 0 otherwise.
#
# First, let's get a list of all categorical variables to make sure they are only contained in the Sex column.

# %%
# Get list of categorical variables
s = (abalone.dtypes == 'object')
object_cols = list(s[s].index)

# Print all values in list.
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['Sex']

# %% [markdown]
# Good. It appears Sex is the only column with object variables. So, let's dummy code this column, and then remove it.

# %%
# Add column to abalone that dummy codes Sex, and then drops the first column.
abalone = pd.concat([abalone, pd.get_dummies(abalone["Sex"], drop_first = True)], axis = 1)

# Delete Sex column.
del abalone['Sex']

# %%
# Look at first few rows to check that sex is now dummy coded.
abalone.head()
# Out:
#    Length  Diameter  Height  Whole_Weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings  I  M
# 0         0.150     15  0  1
# 1         0.070      7  0  1
# 2         0.210      9  0  0
# 3         0.155     10  0  1
# 4         0.055      7  1  0

# %% [markdown]
# Now, whenever Sex = F, this will be our baseline. The categories I and M measure the difference in age between baseline (F) and whichever sex is being indicated.

# %% [markdown]
# # Statistical Model
# If we are interested in making inferences about how the predictors are related to the outcome variable, we need to be sure our model does not violate certain assumptions. Thus, for inference we can actually use the entire dataset (i.e. we can ignore training/testing) and see how our model fits.

# %% [markdown]
# ## Linear Regression via OLS

# %% [markdown]
# First, we can perform a vanilla linear regression. This uses Ordinary Least Squares estimates, meaning optomised coefficients can be immediately computed via the Normal Equation. Note that OLS regression is the only instance where the coefficients that minimise the loss function can be computed one-shot with a closed form solution.

# %%
# Separate target from predictors = y.
y = abalone.Rings

# Separate predictors from target = X.
X = abalone.drop(['Rings'], axis=1)

# Add constant term (i.e. intercept = 1 for all i's)
X = sm.add_constant(X)

# Fit multiple regressions model via OLS regression.
lm_1 = sm.OLS(y, X).fit()

# Plot regression summary.
lm_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Rings   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     551.7
# Date:                Wed, 16 Jun 2021   Prob (F-statistic):               0.00
# Time:                        09:44:24   Log-Likelihood:                -9173.4
# No. Observations:                4175   AIC:                         1.837e+04
# Df Residuals:                    4165   BIC:                         1.843e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
regression_function(X,y)
# Out:
# X_Train Shape = 80 %
# X_Test Shape = 20 %
#
# Coefficients
# [ 0.00000000e+00 -8.00346156e-01  8.89218525e+00  2.22702334e+01
#   9.03085401e+00 -1.97633842e+01 -1.04009816e+01  7.43597771e+00
#  -7.83237190e-01 -7.46750609e-03]
#
# MSE = 4.939137509164217
# R2 = 0.5117690479905841
# Adj_R2 = 0.5105965433027613

# %% [markdown]
# # Check Assumptions
# https://jeffmacaluso.github.io/post/LinearRegressionAssumptions/

# %% [markdown]
# ## Linearity
# There should be a linear association between the model predictors, and the response/dependent variable. Linear regression (and modelling in general) is about explaining a process, and if the dependent variable is not alinear combination of predictors, then the linear regression would be a poor model. This can produce very innacurate predictions because the model will be underfitted. We can check this by plotting all model's predicted values against the actual values (i.e. see the residuals). A perfectly linear association would thus be indicated by a perfectly straight line: Every predicted value would be the actual value.

# %%
# Calculate residuals.
df_results = calculate_residuals(lm_1, X, y)
    
# Plot the actual vs predicted values.
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False, size=7)
        
# Plot a diagonal line.
line_coords = np.arange(df_results.min().min(), df_results.max().max())
plt.plot(line_coords, line_coords,  # X and y points
             color='darkorange', linestyle='--')
plt.title('Actual vs. Predicted')
plt.show()
# Out:
# C:\Users\STPI0560\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Is the relationship linear? It's not perfect, but not to bad. As the actual values get large, the model seems to underpredict them.

# %% [markdown]
# ## Normality Of Error
# Linear regression assume that residuals are normally distributed. Therefore, the residuals should also follow a normal distribution. Violations here can lead to variance estimates becoming inflatted. Here I will use the Anderson-Darling test for normality to test whether this assumption has been violated.

# %%
normal_errors_assumption(lm_1, X, y)
# Out:
# Assumption 2: The error terms are normally distributed
#
# Using the Anderson-Darling test for normal distribution
# p-value from the test - below 0.05 generally means non-normal: 0.0
# Residuals are not normally distributed
# C:\Users\STPI0560\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Assumption not satisfied
#
# Confidence intervals will likely be affected
# Try performing nonlinear transformations on variables

# %% [markdown]
# ## Variance Inflation

# %%
x_temp = sm.add_constant(X)

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_temp.values, i) for i in range(x_temp.values.shape[1])]
vif["features"] = x_temp.columns
print(vif.round(1))
# Out:
#    VIF Factor        features
# 0        75.5           const
# 1        41.1          Length
# 2        42.9        Diameter
# 3         6.7          Height
# 4       109.6    Whole_Weight
# 5        28.6  Shucked weight
# 6        17.5  Viscera weight
# 7        21.6    Shell weight
# 8         2.0               I
# 9         1.4               M

# %% [markdown]
# Well, this looks pretty bad. We need a solution that will reduce the number of features.

# %%
for i in range(vif.shape[0]):
    if vif.iloc[i]['VIF Factor']>10:
        print("Potential Variance Inflation of", vif.iloc[i]['features'], "predictor")
    else:
        print("No Potential Variance Inflation of", vif.iloc[i]['features'], "predictor")
    print(vif.iloc[i]['VIF Factor'])
# Out:
# Potential Variance Inflation of const predictor
# 75.46263737760253
# Potential Variance Inflation of Length predictor
# 41.053914515702395
# Potential Variance Inflation of Diameter predictor
# 42.8777095600903
# No Potential Variance Inflation of Height predictor
# 6.739435932916904
# Potential Variance Inflation of Whole_Weight predictor
# 109.61126098780812
# Potential Variance Inflation of Shucked weight predictor
# 28.612053030819084
# Potential Variance Inflation of Viscera weight predictor
# 17.46870913944597
# Potential Variance Inflation of Shell weight predictor
# 21.58622357164318
# No Potential Variance Inflation of I predictor
# 1.98895634515501
# No Potential Variance Inflation of M predictor
# 1.398146648268473

# %%
corr = abalone.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_7f091_row0_col0,#T_7f091_row1_col1,#T_7f091_row2_col2,#T_7f091_row3_col3,#T_7f091_row4_col4,#T_7f091_row5_col5,#T_7f091_row6_col6,#T_7f091_row7_col7,#T_7f091_row8_col8,#T_7f091_row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7f091_row0_col1,#T_7f091_row1_col0{
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }#T_7f091_row0_col2,#T_7f091_row0_col6,#T_7f091_row1_col5,#T_7f091_row2_col0,#T_7f091_row4_col0,#T_7f091_row5_col1,#T_7f091_row6_col0{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_7f091_row0_col3,#T_7f091_row1_col3,#T_7f091_row3_col0,#T_7f091_row3_col1{
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }#T_7f091_row0_col4,#T_7f091_row1_col4,#T_7f091_row4_col1{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# Let's take a quick look at how each variable

# %%
pairs = sns.pairplot(abalone, vars = abalone.columns[0:7])
pairs.fig.set_size_inches(10,10)

# %% [markdown]
# The predictors are clearly very correlated with one another. This could point to a lot of redundant information, and the possibility that some predictors are not important. For instance, length and diameter might be measuring the smae thing, so perhaps if more data were collected, we would only need to collect 1 of those variables.
#
# However, it is important to note that multicollinearity does not affect predictive power, only inference. Thus, if we were interested in how a predictor was related to the Rings, we would need to remove the effect of multicollinearity. But, if we only want to develop a model for predicting Rings, we do NOT need to remove variables to account for multicollinearity.

# %%
#%matplotlib notebook
# Import library to produce a 3D plot

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x1 = X["Diameter"]
x2 = X["Length"]
ax.scatter(x1, x2, y, c='b', marker='o')
# Set axis labels
ax.set_xlabel('Diameter')
ax.set_ylabel('Length')
ax.set_zlabel('Rings')

# for rotate the axes and update.
for angle in range(0,360): 
    ax.view_init(30,70)
    
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x1 = X["Diameter"]
x2 = X["Length"]
ax.scatter(x1, x2, y, c='b', marker='o')
# Set axis labels
ax.set_xlabel('Diameter')
ax.set_ylabel('Length')
ax.set_zlabel('Rings')

# for rotate the axes and update.
for angle in range(0,360): 
    ax.view_init(60,70)

# %% [markdown]
# ## Homoskedasticity

# %%
 # Calculating residuals for the plot
df_results = calculate_residuals(lm_1, X, y)

    # Plotting the residuals
plt.subplots(figsize=(12, 6))
ax = plt.subplot(111)  # To remove spines
plt.scatter(x=df_results.index, y=df_results.Residuals, alpha=0.5)
plt.plot(np.repeat(0, df_results.index.max()), color='darkorange', linestyle='--')
ax.spines['right'].set_visible(False)  # Removing the right spine
ax.spines['top'].set_visible(False)  # Removing the top spine
plt.title('Residuals')
plt.show()

# %% [markdown]
# # Itteratively Remove Highest VIF Features

# %%
print(vif.sort_values(by=['VIF Factor'], ascending=False))
# Out:
#    VIF Factor        features
# 4  109.611261    Whole_Weight
# 0   75.462637           const
# 2   42.877710        Diameter
# 1   41.053915          Length
# 5   28.612053  Shucked weight
# 7   21.586224    Shell weight
# 6   17.468709  Viscera weight
# 3    6.739436          Height
# 8    1.988956               I
# 9    1.398147               M

# %%
abalone_drop = abalone.drop(['Whole_Weight'], axis=1)

# %%
# Separate target from predictors
y_drop = abalone_drop.Rings
X_drop = abalone_drop.drop(['Rings'], axis=1)

# Divide data into training and testing subsets.
#X_train_drop, X_test_drop, y_train_drop, y_test_drop = train_test_split(X_drop, y_drop, test_size=0.2, random_state=1)

# further divide the training data again to get a validation set.
#X_train_drop, X_val_drop, y_train_drop, y_val_drop = train_test_split(X_train_drop, y_train_drop, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

#regr = linear_model.LinearRegression()
#regr.fit(X_train_drop, y_train_drop)

x_temp = sm.add_constant(X_drop)

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_temp.values, i) for i in range(x_temp.values.shape[1])]
vif["features"] = x_temp.columns
print(vif.sort_values(by=['VIF Factor'], ascending=False))
# Out:
#    VIF Factor        features
# 0   75.373276           const
# 2   42.864626        Diameter
# 1   41.047611          Length
# 5   10.934295  Viscera weight
# 4    9.008457  Shucked weight
# 6    8.265795    Shell weight
# 3    6.733954          Height
# 7    1.986305               I
# 8    1.398090               M

# %%
abalone_drop = abalone_drop.drop(['Diameter'], axis=1)

# %%
# Separate target from predictors
y_drop = abalone_drop.Rings
X_drop = abalone_drop.drop(['Rings'], axis=1)

# Divide data into training and testing subsets.
#X_train_drop, X_test_drop, y_train_drop, y_test_drop = train_test_split(X_drop, y_drop, test_size=0.2, random_state=1)

# further divide the training data again to get a validation set.
#X_train_drop, X_val_drop, y_train_drop, y_val_drop = train_test_split(X_train_drop, y_train_drop, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

#regr = linear_model.LinearRegression()
#regr.fit(X_train_drop, y_train_drop)

x_temp = sm.add_constant(X_drop)

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_temp.values, i) for i in range(x_temp.values.shape[1])]
vif["features"] = x_temp.columns
print(vif.sort_values(by=['VIF Factor'], ascending=False))
# Out:
#    VIF Factor        features
# 0   75.338117           const
# 4   10.908048  Viscera weight
# 1    9.026743          Length
# 3    9.003929  Shucked weight
# 5    8.006904    Shell weight
# 2    6.575107          Height
# 6    1.965176               I
# 7    1.397038               M

# %%
abalone_drop = abalone_drop.drop(['Viscera weight'], axis=1)

# %%
# Separate target from predictors
y_drop = abalone_drop.Rings
X_drop = abalone_drop.drop(['Rings'], axis=1)

# Divide data into training and testing subsets.
X_train_drop, X_test_drop, y_train_drop, y_test_drop = train_test_split(X_drop, y_drop, test_size=0.2, random_state=1)

# further divide the training data again to get a validation set.
X_train_drop, X_val_drop, y_train_drop, y_val_drop = train_test_split(X_train_drop, y_train_drop, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

regr = linear_model.LinearRegression()
regr.fit(X_train_drop, y_train_drop)

x_temp = sm.add_constant(X_train_drop)

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x_temp.values, i) for i in range(x_temp.values.shape[1])]
vif["features"] = x_temp.columns
print(vif.sort_values(by=['VIF Factor'], ascending=False))
# Out:
#    VIF Factor        features
# 0   73.754472           const
# 1    8.839705          Length
# 4    7.474341    Shell weight
# 2    6.736434          Height
# 3    6.103314  Shucked weight
# 5    1.963646               I
# 6    1.388353               M

# %%
X = sm.add_constant(X_drop)
lm_2 = sm.OLS(y_drop, X_drop).fit()
lm_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  Rings   R-squared (uncentered):                   0.953
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                          1.414e+04
# Date:                Wed, 16 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        09:44:46   Log-Likelihood:                         -9328.9
# No. Observations:                4175   AIC:                                  1.867e+04
# Df Residuals:                    4169   BIC:                                  1.871e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
regression_function(X,y)
# Out:
# X_Train Shape = 80 %
# X_Test Shape = 20 %
#
# Coefficients
# [ 0.00000000e+00  5.64408236e+00  2.37681561e+01 -1.14922734e+01
#   1.89957561e+01 -8.68260176e-01 -1.66315263e-02]
#
# MSE = 5.11078751565621
# R2 = 0.49480154183662217
# Adj_R2 = 0.49395287632014906

# %%
# Calculate residuals.
df_results = calculate_residuals(lm_2, X_drop, y_drop)
    
# Plot the actual vs predicted values.
sns.lmplot(x='Actual', y='Predicted', data=df_results, fit_reg=False, size=7)
        
# Plot a diagonal line.
line_coords = np.arange(df_results.min().min(), df_results.max().max())
plt.plot(line_coords, line_coords,  # X and y points
             color='darkorange', linestyle='--')
plt.title('Actual vs. Predicted')
plt.show()
# Out:
# C:\Users\STPI0560\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
normal_errors_assumption(lm_2, X_drop, y_drop)
# Out:
# Assumption 2: The error terms are normally distributed
#
# Using the Anderson-Darling test for normal distribution
# p-value from the test - below 0.05 generally means non-normal: 0.0
# Residuals are not normally distributed
# C:\Users\STPI0560\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Assumption not satisfied
#
# Confidence intervals will likely be affected
# Try performing nonlinear transformations on variables

# %% [markdown]
# # Model Evaluation
#
# Unlike the previous inferential excercise, if we only want to make a model to predict new data, we don't need to worry about violating assumptions. Here, we will use all of the predictors again. Additionally, we want to split the data into 3 distinct sets: training, validation, and testing. All analyses will be conducted between the training and validation sets, witht the testing set only being used for the final check.

# %% [markdown]
# ## Learning Curve
# Use this reference to plot learning curves.
# https://www.dataquest.io/blog/learning-curves-machine-learning/

# %%
# Select sample sizes of training set
train_sizes = [1, 251, 501, 752, 1002, 1253, 1503, 1754, 2004, 2255, 2505]

features = ['Length', 'Diameter', 'Height', 'Whole_Weight', 'Shucked weight', 'Viscera weight', 'Shell weight']
target = 'Rings'
train_sizes, train_scores, validation_scores = learning_curve(
    estimator = LinearRegression(), 
    X = abalone[features],
    y = abalone[target],
    train_sizes = train_sizes,
    cv = 5,
    scoring = 'neg_mean_squared_error')

train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
print('Mean training scores\n\n', pd.Series(train_scores_mean, index = train_sizes))
print('\n', '-' * 20) # separator
print('\nMean validation scores\n\n',pd.Series(validation_scores_mean, index = train_sizes))
# Out:
# Mean training scores
#
#  1      -0.000000
# 251     3.880605
# 501     5.243920
# 752     5.632171
# 1002    5.517779
# 1253    5.196337
# 1503    5.286133
# 1754    5.270546
# 2004    4.942978
# 2255    4.807498
# 2505    5.066657
# dtype: float64
#
#  --------------------
#
# Mean validation scores
#
#  1       35.806707
# 251      9.191547
# 501     10.831606
# 752     10.882828
# 1002     8.199150
# 1253     7.349242
# 1503     5.968775
# 1754     5.557470
# 2004     5.481008
# 2255     5.518837
# 2505     5.406596
# dtype: float64

# %%
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a linear regression model', fontsize = 18, y = 1.03)
plt.legend()
plt.ylim(0,40)
# Out:
# (0.0, 40.0)
